# %%
import pandas as pd
import time
import random
import os
from datetime import datetime
import uuid

# %%
url = ['https://www.espn.com.co/futbol/posiciones/_/liga/esp.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/eng.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ita.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ger.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/fra.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/por.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ned.1']

leagues = ['SPAIN','ENGLAND','ITALY','GERMANY','FRANCE','PORTUGAL','HOLLAND']

# %%
df_leagues = {
    'LEAGUES': leagues,
    'URL': url
}

df_leagues = pd.DataFrame(df_leagues)
df_leagues
# Out:
#     LEAGUES                                                URL
# 0     SPAIN  https://www.espn.com.co/futbol/posiciones/_/li...
# 1   ENGLAND  https://www.espn.com.co/futbol/posiciones/_/li...
# 2     ITALY  https://www.espn.com.co/futbol/posiciones/_/li...
# 3   GERMANY  https://www.espn.com.co/futbol/posiciones/_/li...
# 4    FRANCE  https://www.espn.com.co/futbol/posiciones/_/li...
# 5  PORTUGAL  https://www.espn.com.co/futbol/posiciones/_/li...
# 6   HOLLAND  https://www.espn.com.co/futbol/posiciones/_/li...

# %%
df_leagues["URL"][1]
# Out:
# 'https://www.espn.com.co/futbol/posiciones/_/liga/eng.1'

# %%
df = pd.read_html(df_leagues["URL"][1])
df_0 = df[0]

# %%
df_0
# Out:
#                        2023/2024
# 0                    1ARSArsenal
# 1                  2LIVLiverpool
# 2                3AVLAston Villa
# 3          4TOTTottenham Hotspur
# 4            5MCIManchester City
# 5            6WHUWest Ham United
# 6           7NEWNewcastle United
# 7          8MUNManchester United
# 8     9BHABrighton & Hove Albion
# 9                   10CHEChelsea
# 10  11WOLWolverhampton Wanderers
# 11          12BOUAFC Bournemouth
# 12                   13FULFulham
# 13                14BRNBrentford
# 14           15CRYCrystal Palace
# 15                  16EVEEverton
# 16        17FORNottingham Forest
# 17               18LTNLuton Town
# 18                  19BRNBurnley
# 19   20Sheff UtdSheffield United

# %%
df_1 = df[1]
df_1
# Out:
#      J   G  E   P  GF  GC  DIF  PTS
# 0   18  12  4   2  36  16   20   40
# 1   18  11  6   1  37  16   21   39
# 2   18  12  3   3  38  22   16   39
# 3   18  11  3   4  37  24   13   36
# 4   17  10  4   3  40  20   20   34
# 5   18   9  3   6  31  30    1   30
# 6   18   9  2   7  36  22   14   29
# 7   18   9  1   8  18  23   -5   28
# 8   18   7  6   5  34  31    3   27
# 9   18   6  4   8  29  28    1   22
# 10  18   6  4   8  23  30   -7   22
# 11  17   6  4   7  24  32   -8   22
# 12  18   6  3   9  26  31   -5   21
# 13  17   5  4   8  24  24    0   19
# 14  18   4  6   8  18  26   -8   18
# 15  18   8  2   8  23  22    1   16
# 16  18   3  5  10  19  33  -14   14
# 17  17   3  3  11  18  32  -14   12
# 18  18   3  2  13  18  36  -18   11
# 19  18   2  3  13  13  44  -31    9

# %%
df = pd.concat([df_0, df_1], ignore_index=True, axis=1)
df
# Out:
#                                0   1   2  3   4   5   6   7   8
# 0                    1ARSArsenal  18  12  4   2  36  16  20  40
# 1                  2LIVLiverpool  18  11  6   1  37  16  21  39
# 2                3AVLAston Villa  18  12  3   3  38  22  16  39
# 3          4TOTTottenham Hotspur  18  11  3   4  37  24  13  36
# 4            5MCIManchester City  17  10  4   3  40  20  20  34
# 5            6WHUWest Ham United  18   9  3   6  31  30   1  30
# 6           7NEWNewcastle United  18   9  2   7  36  22  14  29
# 7          8MUNManchester United  18   9  1   8  18  23  -5  28
# 8     9BHABrighton & Hove Albion  18   7  6   5  34  31   3  27
# 9                   10CHEChelsea  18   6  4   8  29  28   1  22
# 10  11WOLWolverhampton Wanderers  18   6  4   8  23  30  -7  22
# 11          12BOUAFC Bournemouth  17   6  4   7  24  32  -8  22
# 12                   13FULFulham  18   6  3   9  26  31  -5  21
# 13                14BRNBrentford  17   5  4   8  24  24   0  19
# 14           15CRYCrystal Palace  18   4  6   8  18  26  -8  18
# 15                  16EVEEverton  18   8  2   8  23  22   1  16
# 16        17FORNottingham Forest  18   3  5  10  19  33 -14  14
# 17               18LTNLuton Town  17   3  3  11  18  32 -14  12
# 18                  19BRNBurnley  18   3  2  13  18  36 -18  11
# 19   20Sheff UtdSheffield United  18   2  3  13  13  44 -31   9

# %%
df = df.rename(columns={0: "TEAM", 1: "G", 2: "W", 3: "D", 4: "L", 5: "GS", 6: "GA", 7: "DIF", 8: "PTS"})
df["TEAM"] = df["TEAM"].apply(lambda x: x[5:] if x[:2].isnumeric()==True else x[4:])
df
# Out:
#                        TEAM   G   W  D   L  GS  GA  DIF  PTS
# 0                   Arsenal  18  12  4   2  36  16   20   40
# 1                 Liverpool  18  11  6   1  37  16   21   39
# 2               Aston Villa  18  12  3   3  38  22   16   39
# 3         Tottenham Hotspur  18  11  3   4  37  24   13   36
# 4           Manchester City  17  10  4   3  40  20   20   34
# 5           West Ham United  18   9  3   6  31  30    1   30
# 6          Newcastle United  18   9  2   7  36  22   14   29
# 7         Manchester United  18   9  1   8  18  23   -5   28
# 8    Brighton & Hove Albion  18   7  6   5  34  31    3   27
# 9                   Chelsea  18   6  4   8  29  28    1   22
# 10  Wolverhampton Wanderers  18   6  4   8  23  30   -7   22
# 11          AFC Bournemouth  17   6  4   7  24  32   -8   22
# 12                   Fulham  18   6  3   9  26  31   -5   21
# 13                Brentford  17   5  4   8  24  24    0   19
# 14           Crystal Palace  18   4  6   8  18  26   -8   18
# 15                  Everton  18   8  2   8  23  22    1   16
# 16        Nottingham Forest  18   3  5  10  19  33  -14   14
# 17               Luton Town  17   3  3  11  18  32  -14   12
# 18                  Burnley  18   3  2  13  18  36  -18   11
# 19   ff UtdSheffield United  18   2  3  13  13  44  -31    9

# %%
df["LEAGUE"] = df_leagues["LEAGUES"][1]
df
# Out:
#                        TEAM   G   W  D   L  GS  GA  DIF  PTS   LEAGUE
# 0                   Arsenal  18  12  4   2  36  16   20   40  ENGLAND
# 1                 Liverpool  18  11  6   1  37  16   21   39  ENGLAND
# 2               Aston Villa  18  12  3   3  38  22   16   39  ENGLAND
# 3         Tottenham Hotspur  18  11  3   4  37  24   13   36  ENGLAND
# 4           Manchester City  17  10  4   3  40  20   20   34  ENGLAND
# 5           West Ham United  18   9  3   6  31  30    1   30  ENGLAND
# 6          Newcastle United  18   9  2   7  36  22   14   29  ENGLAND
# 7         Manchester United  18   9  1   8  18  23   -5   28  ENGLAND
# 8    Brighton & Hove Albion  18   7  6   5  34  31    3   27  ENGLAND
# 9                   Chelsea  18   6  4   8  29  28    1   22  ENGLAND
# 10  Wolverhampton Wanderers  18   6  4   8  23  30   -7   22  ENGLAND
# 11          AFC Bournemouth  17   6  4   7  24  32   -8   22  ENGLAND
# 12                   Fulham  18   6  3   9  26  31   -5   21  ENGLAND
# 13                Brentford  17   5  4   8  24  24    0   19  ENGLAND
# 14           Crystal Palace  18   4  6   8  18  26   -8   18  ENGLAND
# 15                  Everton  18   8  2   8  23  22    1   16  ENGLAND
# 16        Nottingham Forest  18   3  5  10  19  33  -14   14  ENGLAND
# 17               Luton Town  17   3  3  11  18  32  -14   12  ENGLAND
# 18                  Burnley  18   3  2  13  18  36  -18   11  ENGLAND
# 19   ff UtdSheffield United  18   2  3  13  13  44  -31    9  ENGLAND
